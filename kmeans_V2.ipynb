# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
import os

if os.path.isfile('customers_cleaned_v2.pkl'):
    print("File exists")
else:
    print("File does not exist")


print(os.getcwd())
# Out:
# File exists
# C:\Users\adria\Data Science for Biz

# %%
df = pd.read_pickle('customers_cleaned.pkl')  # replace 'filename.pkl' with your file path
df.head()
# Out:
#                                          customer_id   FN  Active  \
# 0  00000dbacae5abe5e23885899a1fa44253a17956c6d1c3...  NaN     NaN
# 1  0000423b00ade91418cceaf3b26c6af3dd342b51fd051e...  NaN     NaN
# 2  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...  NaN     NaN
# 3  00005ca1c9ed5f5146b52ac8639a40ca9d57aeff4d1bd2...  NaN     NaN
# 4  00006413d8573cd20ed7128e53b7b13819fe5cfc2d801f...  1.0     1.0
#
#   club_member_status fashion_news_frequency   age  \
# 0             ACTIVE                   NONE  49.0
# 1             ACTIVE                   NONE  25.0
# 2             ACTIVE                   NONE  24.0
# 3             ACTIVE                   NONE  54.0
# 4             ACTIVE              Regularly  52.0
#
#                                          postal_code age_bin age_group  \
# 0  52043ee2162cf5aa7ee79974281641c6f11a68d276429a...   45-54     Adult
# 1  2973abc54daa8a5f8ccfe9362140c63247c5eee03f1d93...   25-34     Adult
# 2  64f17e6a330a85798e4998f62d0930d14db8db1c054af6...   25-34     Young
# 3  5d36574f52495e81f019b680c843c443bd343d5ca5b1c2...   55-64    Senior
# 4  25fa5ddee9aac01b35208d01736e57942317d756b32ddd...   45-54    Senior
#
#    Overall_transaction_count  ...  Graphic_bought_most  \
# 0                       21.0  ...                Solid
# 1                       86.0  ...                Solid
# 2                       18.0  ...                Solid
# 3                        2.0  ...                Solid
# 4                       13.0  ...                Solid
#
#    Perceived_color_bought_most         Section_bought_most  \
# 0                         Dark            Womens Tailoring
# 1                         Dark  Womens Swimwear, beachwear
# 2                         Dark       Men Suits & Tailoring
# 3                         Dark            Ladies H&M Sport
# 4                         Dark             Womens Lingerie
#
#    Earliest_transaction_date  Recency   Tenure Transaction_count_revised  \
# 0                 2018-12-27  17 days 618 days                      19.0
# 1                 2018-09-21  76 days 656 days                      64.0
# 2                 2018-09-20   7 days 726 days                      14.0
# 3                 2019-06-09 471 days   0 days                       2.0
# 4                 2018-10-12  41 days 670 days                      12.0
#
#   Recency_days Tenure_days Unique_items
# 0         17.0       618.0         19.0
# 1         76.0       656.0         64.0
# 2          7.0       726.0         14.0
# 3        471.0         0.0          2.0
# 4         41.0       670.0         12.0
#
# [5 rows x 25 columns]

# %%
df.describe()
# Out:
#              FN    Active           age  Overall_transaction_count  \
# count  476930.0  464404.0  1.356119e+06               1.362281e+06
# mean        1.0       1.0  3.638696e+01               2.333463e+01
# std         0.0       0.0  1.431363e+01               3.924225e+01
# min         1.0       1.0  1.600000e+01               1.000000e+00
# 25%         1.0       1.0  2.400000e+01               3.000000e+00
# 50%         1.0       1.0  3.200000e+01               9.000000e+00
# 75%         1.0       1.0  4.900000e+01               2.700000e+01
# max         1.0       1.0  9.900000e+01               1.895000e+03
#
#        Overall_transaction_count_channel_1  \
# count                        737118.000000
# mean                             12.763848
# std                              16.013591
# min                               1.000000
# 25%                               3.000000
# 50%                               7.000000
# 75%                              16.000000
# max                             789.000000
#
#        Overall_transaction_count_channel_2  Overall_transacted  \
# count                         1.108418e+06        1.362281e+06
# mean                          2.019081e+01        3.831376e+02
# std                           3.733113e+01        7.065734e+02
# min                           1.000000e+00        4.500000e-01
# 25%                           3.000000e+00        5.196000e+01
# 50%                           7.000000e+00        1.449000e+02
# 75%                           2.100000e+01        4.137000e+02
# max                           1.534000e+03        3.402908e+04
#
#                            Recency                       Tenure  \
# count                      1362281                      1362281
# mean   235 days 03:33:44.962838052  273 days 09:22:39.258772616
# std    221 days 02:51:03.569191548  269 days 23:05:18.867157276
# min                0 days 00:00:00              0 days 00:00:00
# 25%               48 days 00:00:00              0 days 00:00:00
# 50%              151 days 00:00:00            206 days 00:00:00
# 75%              398 days 00:00:00            549 days 00:00:00
# max              733 days 00:00:00            733 days 00:00:00
#
#        Transaction_count_revised  Recency_days   Tenure_days  Unique_items
# count               1.362281e+06  1.362281e+06  1.362281e+06  1.371980e+06
# mean                2.004464e+01  2.351484e+02  2.733907e+02  1.990294e+01
# std                 3.198025e+01  2.211188e+02  2.699620e+02  3.191123e+01
# min                 1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%                 3.000000e+00  4.800000e+01  0.000000e+00  3.000000e+00
# 50%                 8.000000e+00  1.510000e+02  2.060000e+02  8.000000e+00
# 75%                 2.400000e+01  3.980000e+02  5.490000e+02  2.300000e+01
# max                 1.346000e+03  7.330000e+02  7.330000e+02  1.346000e+03

# %%
most_recent= df['Last_transaction_date'].max()
most_recent

df['First_Transaction'] = (most_recent - df['Earliest_transaction_date']).dt.days

# %%
df['Recency_days'] = pd.to_numeric(df['Recency_days'], errors='coerce')

# Perform the filter operation
filtered_df = df[(df['age'] >= 35) & (df['age'] <= 44) & (df['Active']==1.0)& (df['fashion_news_frequency']=='Regularly')]
filtered_df
# Out:
#                                                customer_id   FN  Active  \
# 19       0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5...  1.0     1.0
# 25       000114c6996ef5703a8d455faf2103f8488d3928348e07...  1.0     1.0
# 38       0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37...  1.0     1.0
# 123      00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cd...  1.0     1.0
# 236      000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae47...  1.0     1.0
# ...                                                    ...  ...     ...
# 1371883  fffb00d134c84e6b71d3734c5261305fd2b1d200db0d17...  1.0     1.0
# 1371901  fffbe1daa0362090117b76308b8e52266db42e32ee1e7b...  1.0     1.0
# 1371916  fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda...  1.0     1.0
# 1371951  fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b...  1.0     1.0
# 1371956  fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10...  1.0     1.0
#
#         club_member_status fashion_news_frequency   age  \
# 19                  ACTIVE              Regularly  41.0
# 25              PRE-CREATE              Regularly  40.0
# 38                  ACTIVE              Regularly  44.0
# 123                 ACTIVE              Regularly  44.0
# 236                 ACTIVE              Regularly  40.0
# ...                    ...                    ...   ...
# 1371883             ACTIVE              Regularly  40.0
# 1371901             ACTIVE              Regularly  39.0
# 1371916             ACTIVE              Regularly  43.0
# 1371951             ACTIVE              Regularly  44.0
# 1371956             ACTIVE              Regularly  38.0
#
#                                                postal_code age_bin age_group  \
# 19       5b5f53c673d0fc0774fbbd3b2174b799c99f12029605ee...   35-44     Adult
# 25       364bc321c321e34c5a94d539f8614609aa3d59fc5bbceb...   35-44     Adult
# 38       930b19ae7db8abb5a27f4da10217755a7305b4c452f5e0...   45-54     Adult
# 123      95f592273622e57fdd99316547b96e76756308a50dff35...   45-54     Adult
# 236      14700fd992c14b1e240dbad4f4f8ed5537c3bc1a657e2b...   35-44     Adult
# ...                                                    ...     ...       ...
# 1371883  2bad628985a95000d7bac965fa9673b06a629b09987157...   35-44     Adult
# 1371901  d4c3dfc092cc9cefbefac284c394bf175dbe2f74cdcaae...   35-44     Adult
# 1371916  4de16ae082b161f3dcda04cecfed7f5c48508817a67cf6...   35-44     Adult
# 1371951  8a9cc8fcd8127297902050ce7b1c1f148c498ccef80e1c...   45-54     Adult
# 1371956  aa43c57bc1e17b465730f42bdbf43c6febbf5406dc724a...   35-44     Adult
#
#          Overall_transaction_count  ...  Perceived_color_bought_most  \
# 19                             7.0  ...                 Medium Dusty
# 25                            18.0  ...                         Dark
# 38                           679.0  ...                         Dark
# 123                            4.0  ...                         Dark
# 236                           21.0  ...                         Dark
# ...                            ...  ...                          ...
# 1371883                        4.0  ...                         Dark
# 1371901                        1.0  ...                         Dark
# 1371916                        1.0  ...                        Light
# 1371951                       15.0  ...                         Dark
# 1371956                        7.0  ...                 Medium Dusty
#
#                 Section_bought_most Earliest_transaction_date  Recency  \
# 19       Womens Swimwear, beachwear                2019-06-22 440 days
# 25       Womens Everyday Collection                2019-02-20  94 days
# 38       Womens Everyday Collection                2018-10-01   8 days
# 123                   Womens Casual                2019-12-06  59 days
# 236              Divided Collection                2019-02-14 263 days
# ...                             ...                       ...      ...
# 1371883          Divided Collection                2020-04-06 169 days
# 1371901                    Kids Boy                2018-11-29 663 days
# 1371916  Womens Everyday Collection                2019-03-28 544 days
# 1371951              Divided Basics                2018-11-11 370 days
# 1371956            Womens Tailoring                2018-09-29 101 days
#
#           Tenure Transaction_count_revised Recency_days Tenure_days  \
# 19       18 days                       7.0        440.0        18.0
# 25      486 days                      18.0         94.0       486.0
# 38      714 days                     555.0          8.0       714.0
# 123     232 days                       3.0         59.0       232.0
# 236     323 days                      21.0        263.0       323.0
# ...          ...                       ...          ...         ...
# 1371883   0 days                       4.0        169.0         0.0
# 1371901   0 days                       1.0        663.0         0.0
# 1371916   0 days                       1.0        544.0         0.0
# 1371951 311 days                      15.0        370.0       311.0
# 1371956 623 days                       7.0        101.0       623.0
#
#         Unique_items First_Transaction
# 19               7.0             458.0
# 25              18.0             580.0
# 38             555.0             722.0
# 123              3.0             291.0
# 236             21.0             586.0
# ...              ...               ...
# 1371883          4.0             169.0
# 1371901          1.0             663.0
# 1371916          1.0             544.0
# 1371951         15.0             681.0
# 1371956          7.0             724.0
#
# [56584 rows x 26 columns]

# %%
# Assuming your DataFrame is stored in a variable called 'df'
filtered_df.dropna(subset=['Recency_days'], inplace=True)

# Display the modified DataFrame
print(filtered_df)
# Out:
#                                                customer_id   FN  Active  \
# 19       0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5...  1.0     1.0
# 25       000114c6996ef5703a8d455faf2103f8488d3928348e07...  1.0     1.0
# 38       0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37...  1.0     1.0
# 123      00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cd...  1.0     1.0
# 236      000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae47...  1.0     1.0
# ...                                                    ...  ...     ...
# 1371883  fffb00d134c84e6b71d3734c5261305fd2b1d200db0d17...  1.0     1.0
# 1371901  fffbe1daa0362090117b76308b8e52266db42e32ee1e7b...  1.0     1.0
# 1371916  fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda...  1.0     1.0
# 1371951  fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b...  1.0     1.0
# 1371956  fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10...  1.0     1.0
#
#         club_member_status fashion_news_frequency   age  \
# 19                  ACTIVE              Regularly  41.0
# 25              PRE-CREATE              Regularly  40.0
# 38                  ACTIVE              Regularly  44.0
# 123                 ACTIVE              Regularly  44.0
# 236                 ACTIVE              Regularly  40.0
# ...                    ...                    ...   ...
# 1371883             ACTIVE              Regularly  40.0
# 1371901             ACTIVE              Regularly  39.0
# 1371916             ACTIVE              Regularly  43.0
# 1371951             ACTIVE              Regularly  44.0
# 1371956             ACTIVE              Regularly  38.0
#
#                                                postal_code age_bin age_group  \
# 19       5b5f53c673d0fc0774fbbd3b2174b799c99f12029605ee...   35-44     Adult
# 25       364bc321c321e34c5a94d539f8614609aa3d59fc5bbceb...   35-44     Adult
# 38       930b19ae7db8abb5a27f4da10217755a7305b4c452f5e0...   45-54     Adult
# 123      95f592273622e57fdd99316547b96e76756308a50dff35...   45-54     Adult
# 236      14700fd992c14b1e240dbad4f4f8ed5537c3bc1a657e2b...   35-44     Adult
# ...                                                    ...     ...       ...
# 1371883  2bad628985a95000d7bac965fa9673b06a629b09987157...   35-44     Adult
# 1371901  d4c3dfc092cc9cefbefac284c394bf175dbe2f74cdcaae...   35-44     Adult
# 1371916  4de16ae082b161f3dcda04cecfed7f5c48508817a67cf6...   35-44     Adult
# 1371951  8a9cc8fcd8127297902050ce7b1c1f148c498ccef80e1c...   45-54     Adult
# 1371956  aa43c57bc1e17b465730f42bdbf43c6febbf5406dc724a...   35-44     Adult
#
#          Overall_transaction_count  ...  Perceived_color_bought_most  \
# 19                             7.0  ...                 Medium Dusty
# 25                            18.0  ...                         Dark
# 38                           679.0  ...                         Dark
# 123                            4.0  ...                         Dark
# 236                           21.0  ...                         Dark
# ...                            ...  ...                          ...
# 1371883                        4.0  ...                         Dark
# 1371901                        1.0  ...                         Dark
# 1371916                        1.0  ...                        Light
# 1371951                       15.0  ...                         Dark
# 1371956                        7.0  ...                 Medium Dusty
#
#                 Section_bought_most Earliest_transaction_date  Recency  \
# 19       Womens Swimwear, beachwear                2019-06-22 440 days
# 25       Womens Everyday Collection                2019-02-20  94 days
# 38       Womens Everyday Collection                2018-10-01   8 days
# 123                   Womens Casual                2019-12-06  59 days
# 236              Divided Collection                2019-02-14 263 days
# ...                             ...                       ...      ...
# 1371883          Divided Collection                2020-04-06 169 days
# 1371901                    Kids Boy                2018-11-29 663 days
# 1371916  Womens Everyday Collection                2019-03-28 544 days
# 1371951              Divided Basics                2018-11-11 370 days
# 1371956            Womens Tailoring                2018-09-29 101 days
#
#           Tenure Transaction_count_revised Recency_days Tenure_days  \
# 19       18 days                       7.0        440.0        18.0
# 25      486 days                      18.0         94.0       486.0
# 38      714 days                     555.0          8.0       714.0
# 123     232 days                       3.0         59.0       232.0
# 236     323 days                      21.0        263.0       323.0
# ...          ...                       ...          ...         ...
# 1371883   0 days                       4.0        169.0         0.0
# 1371901   0 days                       1.0        663.0         0.0
# 1371916   0 days                       1.0        544.0         0.0
# 1371951 311 days                      15.0        370.0       311.0
# 1371956 623 days                       7.0        101.0       623.0
#
#         Unique_items First_Transaction
# 19               7.0             458.0
# 25              18.0             580.0
# 38             555.0             722.0
# 123              3.0             291.0
# 236             21.0             586.0
# ...              ...               ...
# 1371883          4.0             169.0
# 1371901          1.0             663.0
# 1371916          1.0             544.0
# 1371951         15.0             681.0
# 1371956          7.0             724.0
#
# [56185 rows x 26 columns]
# C:\Users\adria\AppData\Local\Temp\ipykernel_15644\4191026604.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.dropna(subset=['Recency_days'], inplace=True)

# %%
filtered_df = filtered_df.rename(columns={'Overall_transaction_count': 'Transaction','Recency': 'Recency (Days)', 'Recency_days': 'Recency','Tenure': 'Tenure (Days)', 'Tenure_days':'Tenure','Overall_transacted':'Total_Value'})
print(filtered_df.columns)
# Out:
# Index(['customer_id', 'FN', 'Active', 'club_member_status',
#        'fashion_news_frequency', 'age', 'postal_code', 'age_bin', 'age_group',
#        'Transaction', 'Overall_transaction_count_channel_1',
#        'Overall_transaction_count_channel_2', 'Last_transaction_date',
#        'Total_Value', 'Product_type_bought_most', 'Graphic_bought_most',
#        'Perceived_color_bought_most', 'Section_bought_most',
#        'Earliest_transaction_date', 'Recency (Days)', 'Tenure (Days)',
#        'Transaction_count_revised', 'Recency', 'Tenure', 'Unique_items',
#        'First_Transaction'],
#       dtype='object')

# %%
for col in filtered_df.columns:
    proportion_missing = np.mean(filtered_df[col].isnull())
    print('{}: {:.2f}%'.format(col, proportion_missing*100))
# Out:
# customer_id: 0.00%
# FN: 0.00%
# Active: 0.00%
# club_member_status: 0.09%
# fashion_news_frequency: 0.00%
# age: 0.00%
# postal_code: 0.00%
# age_bin: 0.00%
# age_group: 0.00%
# Transaction: 0.00%
# Overall_transaction_count_channel_1: 37.53%
# Overall_transaction_count_channel_2: 23.29%
# Last_transaction_date: 0.00%
# Total_Value: 0.00%
# Product_type_bought_most: 0.00%
# Graphic_bought_most: 0.00%
# Perceived_color_bought_most: 0.00%
# Section_bought_most: 0.00%
# Earliest_transaction_date: 0.00%
# Recency (Days): 0.00%
# Tenure (Days): 0.00%
# Transaction_count_revised: 0.00%
# Recency: 0.00%
# Tenure: 0.00%
# Unique_items: 0.00%
# First_Transaction: 0.00%

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

filtered_df['First_Transaction'] = pd.to_numeric(df['First_Transaction'], errors='coerce')

# Calculate correlations
correlation = filtered_df[['Total_Value',"Transaction", 'Recency', 'Tenure', 'Unique_items', 'First_Transaction']].corr()

# Create a heatmap
plt.figure(figsize=(10,8))
sns.heatmap(correlation, annot=True, cmap='coolwarm', center=0)

plt.show()

# %%
# # Calculate correlations
# correlation = new_df[['Total_Value', 'Months_With_Transactions', 'Price_Per_Item', 'Items_Per_Transaction', "Earliest_Transaction", "Latest_Transaction", "Per_Transaction_Value", "Unique_Items"]].corr()

# # Create a heatmap
# plt.figure(figsize=(10,8))
# sns.heatmap(correlation, annot=True, cmap='coolwarm', center=0)

# plt.show()

# %%
processed_df = filtered_df[['customer_id','Total_Value',"Transaction", 'Recency', 'Tenure', 'Unique_items','First_Transaction', 'Overall_transaction_count_channel_1', 'Overall_transaction_count_channel_2']].copy()
processed_df.set_index('customer_id', inplace=True)

processed_df['Overall_transaction_count_channel_1'].fillna(0, inplace=True)
processed_df['Overall_transaction_count_channel_2'].fillna(0, inplace=True)

processed_df = processed_df.rename(columns={'Overall_transaction_count_channel_1': 'Transaction_Channel1', 'Overall_transaction_count_channel_2':'Transaction_Channel2'})

processed_df
# Out:
#                                                     Total_Value  Transaction  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...        82.94          7.0
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...       198.82         18.0
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...     15025.47        679.0
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...        50.06          4.0
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...       234.79         21.0
# ...                                                         ...          ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...        53.96          4.0
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...         4.99          1.0
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...        19.99          1.0
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...       180.55         15.0
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...        71.53          7.0
#
#                                                     Recency  Tenure  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...    440.0    18.0
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...     94.0   486.0
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...      8.0   714.0
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...     59.0   232.0
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...    263.0   323.0
# ...                                                     ...     ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...    169.0     0.0
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...    663.0     0.0
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...    544.0     0.0
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...    370.0   311.0
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...    101.0   623.0
#
#                                                     Unique_items  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...           7.0
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...          18.0
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...         555.0
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...           3.0
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...          21.0
# ...                                                          ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...           4.0
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...           1.0
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...           1.0
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...          15.0
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...           7.0
#
#                                                     First_Transaction  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...              458.0
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...              580.0
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...              722.0
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...              291.0
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...              586.0
# ...                                                               ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...              169.0
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...              663.0
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...              544.0
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...              681.0
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...              724.0
#
#                                                     Transaction_Channel1  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...                   0.0
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...                   0.0
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...                 117.0
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...                   0.0
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...                  13.0
# ...                                                                  ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...                   0.0
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...                   1.0
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...                   1.0
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...                   0.0
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...                   3.0
#
#                                                     Transaction_Channel2
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...                   7.0
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...                  18.0
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...                 562.0
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...                   4.0
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...                   8.0
# ...                                                                  ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...                   4.0
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...                   0.0
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...                   0.0
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...                  15.0
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...                   4.0
#
# [56185 rows x 8 columns]

# %%
processed_df.describe()
# Out:
#         Total_Value   Transaction       Recency        Tenure  Unique_items  \
# count  56185.000000  56185.000000  56185.000000  56185.000000  56185.000000
# mean     497.511053     31.287692    244.624188    301.723289     26.601744
# std      910.697355     52.589036    237.515960    278.021928     42.129977
# min        0.890000      1.000000      0.000000      0.000000      1.000000
# 25%       59.980000      4.000000     41.000000      0.000000      4.000000
# 50%      175.900000     12.000000    135.000000    275.000000     11.000000
# 75%      533.170000     36.000000    439.000000    593.000000     31.000000
# max    17700.230000    950.000000    733.000000    733.000000    765.000000
#
#        First_Transaction  Transaction_Channel1  Transaction_Channel2
# count       56185.000000          56185.000000          56185.000000
# mean          546.347477              8.955237             22.332455
# std           204.124640             16.563488             46.955261
# min             0.000000              0.000000              0.000000
# 25%           448.000000              0.000000              1.000000
# 50%           636.000000              3.000000              6.000000
# 75%           703.000000             11.000000             22.000000
# max           733.000000            393.000000            857.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create subplots
fig, axes = plt.subplots(4, 2, figsize=(12, 10))

# Plot distribution 1
sns.histplot(data= processed_df, x='Total_Value', kde=True, ax=axes[0, 0])
axes[0, 0].set_title('Total Value')
axes[0, 0].set_xlabel('Values')
axes[0, 0].set_ylabel('Frequency')
# axes[0, 0].set_xlim(0, 6000)

# Plot distribution 2
sns.histplot(data= processed_df, x='Transaction', kde=True, ax=axes[0, 1])
axes[0, 1].set_title('Transaction')
axes[0, 1].set_xlabel('Values')
axes[0, 1].set_ylabel('Frequency')
# axes[0, 1].set_xlim(0, 13)

# Plot distribution 3
sns.histplot(data= processed_df, x='Recency', kde=True, ax=axes[1, 0])
axes[1, 0].set_title('Recency')
axes[1, 0].set_xlabel('Values')
axes[1, 0].set_ylabel('Frequency')
# axes[1, 0].set_xlim(0, 20)

# Plot distribution 4
sns.histplot(data= processed_df, x='Tenure', kde=True, ax=axes[1, 1])
axes[1, 1].set_title('Tenure')
axes[1, 1].set_xlabel('Values')
axes[1, 1].set_ylabel('Frequency')
# axes[1, 1].set_xlim(0, 400)

# Plot distribution 5
sns.histplot(data= processed_df, x='Unique_items', kde=True, ax=axes[2, 0])
axes[2, 0].set_title('Unique Items')
axes[2, 0].set_xlabel('Values')
axes[2, 0].set_ylabel('Frequency')
# axes[2, 1].set_xlim(0, 400)

# Plot distribution 6
sns.histplot(data= processed_df, x='First_Transaction', kde=True, ax=axes[2, 1])
axes[2, 1].set_title('First Transaction')
axes[2, 1].set_xlabel('Values')
axes[2, 1].set_ylabel('Frequency')
# axes[2, 1].set_xlim(0, 400)

# Plot distribution 7
sns.histplot(data= processed_df, x='Transaction_Channel1', kde=True, ax=axes[3, 0])
axes[3, 0].set_title('First Transaction')
axes[3, 0].set_xlabel('Values')
axes[3, 0].set_ylabel('Frequency')
# axes[2, 1].set_xlim(0, 400)

# Plot distribution 8
sns.histplot(data= processed_df, x='Transaction_Channel2', kde=True, ax=axes[3, 1])
axes[3, 1].set_title('First Transaction')
axes[3, 1].set_xlabel('Values')
axes[3, 1].set_ylabel('Frequency')
# axes[2, 1].set_xlim(0, 400)


# Adjust layout
plt.tight_layout()

# Display the plots
plt.show()

# %%
processed_df['Tr_Total_Value'] = np.log(processed_df['Total_Value'])
processed_df['Tr_Transaction'] = np.log(processed_df['Transaction'])
processed_df['Tr_Unique_Items'] = np.log(processed_df['Unique_items'])
processed_df['Tr_First_Transaction'] = np.log((processed_df['First_Transaction'])+1)

processed_df['Tr_Recency'] = np.log((processed_df['Recency'])+1)
processed_df['Tr_Tenure'] = np.log((processed_df['Tenure'])+1)

processed_df['Tr_Transaction_Channel1'] = np.log((processed_df['Transaction_Channel1'])+1)
processed_df['Tr_Transaction_Channel2'] = np.log((processed_df['Transaction_Channel2'])+1)
                                        
processed_df
# Out:
#                                                     Total_Value  Transaction  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...        82.94          7.0
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...       198.82         18.0
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...     15025.47        679.0
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...        50.06          4.0
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...       234.79         21.0
# ...                                                         ...          ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...        53.96          4.0
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...         4.99          1.0
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...        19.99          1.0
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...       180.55         15.0
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...        71.53          7.0
#
#                                                     Recency  Tenure  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...    440.0    18.0
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...     94.0   486.0
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...      8.0   714.0
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...     59.0   232.0
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...    263.0   323.0
# ...                                                     ...     ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...    169.0     0.0
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...    663.0     0.0
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...    544.0     0.0
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...    370.0   311.0
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...    101.0   623.0
#
#                                                     Unique_items  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...           7.0
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...          18.0
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...         555.0
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...           3.0
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...          21.0
# ...                                                          ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...           4.0
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...           1.0
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...           1.0
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...          15.0
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...           7.0
#
#                                                     First_Transaction  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...              458.0
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...              580.0
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...              722.0
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...              291.0
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...              586.0
# ...                                                               ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...              169.0
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...              663.0
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...              544.0
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...              681.0
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...              724.0
#
#                                                     Transaction_Channel1  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...                   0.0
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...                   0.0
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...                 117.0
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...                   0.0
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...                  13.0
# ...                                                                  ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...                   0.0
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...                   1.0
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...                   1.0
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...                   0.0
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...                   3.0
#
#                                                     Transaction_Channel2  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...                   7.0
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...                  18.0
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...                 562.0
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...                   4.0
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...                   8.0
# ...                                                                  ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...                   4.0
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...                   0.0
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...                   0.0
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...                  15.0
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...                   4.0
#
#                                                     Tr_Total_Value  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...        4.418117
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...        5.292400
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...        9.617502
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...        3.913222
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...        5.458691
# ...                                                            ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...        3.988243
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...        1.607436
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...        2.995232
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...        5.196008
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...        4.270117
#
#                                                     Tr_Transaction  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...        1.945910
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...        2.890372
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...        6.520621
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...        1.386294
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...        3.044522
# ...                                                            ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...        1.386294
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...        0.000000
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...        0.000000
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...        2.708050
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...        1.945910
#
#                                                     Tr_Unique_Items  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...         1.945910
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...         2.890372
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...         6.318968
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...         1.098612
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...         3.044522
# ...                                                             ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...         1.386294
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...         0.000000
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...         0.000000
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...         2.708050
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...         1.945910
#
#                                                     Tr_First_Transaction  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...              6.129050
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...              6.364751
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...              6.583409
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...              5.676754
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...              6.375025
# ...                                                                  ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...              5.135798
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...              6.498282
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...              6.300786
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...              6.525030
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...              6.586172
#
#                                                     Tr_Recency  Tr_Tenure  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...    6.089045   2.944439
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...    4.553877   6.188264
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...    2.197225   6.572283
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...    4.094345   5.451038
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...    5.575949   5.780744
# ...                                                        ...        ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...    5.135798   0.000000
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...    6.498282   0.000000
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...    6.300786   0.000000
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...    5.916202   5.743003
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...    4.624973   6.436150
#
#                                                     Tr_Transaction_Channel1  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...                 0.000000
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...                 0.000000
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...                 4.770685
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...                 0.000000
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...                 2.639057
# ...                                                                     ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...                 0.000000
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...                 0.693147
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...                 0.693147
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...                 0.000000
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...                 1.386294
#
#                                                     Tr_Transaction_Channel2
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...                 2.079442
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...                 2.944439
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...                 6.333280
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...                 1.609438
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...                 2.197225
# ...                                                                     ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...                 1.609438
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...                 0.000000
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...                 0.000000
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...                 2.772589
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...                 1.609438
#
# [56185 rows x 16 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create subplots
fig, axes = plt.subplots(4, 2, figsize=(12, 10))

# Plot distribution 1
sns.histplot(data= processed_df, x='Tr_Total_Value', kde=True, ax=axes[0, 0])
axes[0, 0].set_title('Total Value')
axes[0, 0].set_xlabel('Values')
axes[0, 0].set_ylabel('Frequency')
# axes[0, 0].set_xlim(0, 6000)

# Plot distribution 2
sns.histplot(data= processed_df, x='Tr_Transaction', kde=True, ax=axes[0, 1])
axes[0, 1].set_title('Transaction')
axes[0, 1].set_xlabel('Values')
axes[0, 1].set_ylabel('Frequency')
# axes[0, 1].set_xlim(0, 13)

# Plot distribution 3
sns.histplot(data= processed_df, x='Tr_Recency', kde=True, ax=axes[1, 0])
axes[1, 0].set_title('Recency')
axes[1, 0].set_xlabel('Values')
axes[1, 0].set_ylabel('Frequency')
# axes[1, 0].set_xlim(0, 20)

# Plot distribution 4
sns.histplot(data= processed_df, x='Tr_Tenure', kde=True, ax=axes[1, 1])
axes[1, 1].set_title('Tenure')
axes[1, 1].set_xlabel('Values')
axes[1, 1].set_ylabel('Frequency')
# axes[1, 1].set_xlim(0, 400)

# Plot distribution 5
sns.histplot(data= processed_df, x='Tr_Unique_Items', kde=True, ax=axes[2, 0])
axes[2, 0].set_title('Unique Items')
axes[2, 0].set_xlabel('Values')
axes[2, 0].set_ylabel('Frequency')
# axes[2, 1].set_xlim(0, 400)

# Plot distribution 6
sns.histplot(data= processed_df, x='Tr_First_Transaction', kde=True, ax=axes[2, 1])
axes[2, 1].set_title('First Transaction')
axes[2, 1].set_xlabel('Values')
axes[2, 1].set_ylabel('Frequency')
# axes[2, 1].set_xlim(0, 400)

# Plot distribution 7
sns.histplot(data= processed_df, x='Tr_Transaction_Channel1', kde=True, ax=axes[3, 0])
axes[3, 0].set_title('Transaction Channel1')
axes[3, 0].set_xlabel('Values')
axes[3, 0].set_ylabel('Frequency')
# axes[2, 1].set_xlim(0, 400)

# Plot distribution 8
sns.histplot(data= processed_df, x='Tr_Transaction_Channel2', kde=True, ax=axes[3, 1])
axes[3, 1].set_title('Transaction Channel 2')
axes[3, 1].set_xlabel('Values')
axes[3, 1].set_ylabel('Frequency')
# axes[2, 1].set_xlim(0, 400)

# Adjust layout
plt.tight_layout()

# Display the plots
plt.show()

# %%
processed_df.describe()
# Out:
#         Total_Value   Transaction       Recency        Tenure  Unique_items  \
# count  56185.000000  56185.000000  56185.000000  56185.000000  56185.000000
# mean     497.511053     31.287692    244.624188    301.723289     26.601744
# std      910.697355     52.589036    237.515960    278.021928     42.129977
# min        0.890000      1.000000      0.000000      0.000000      1.000000
# 25%       59.980000      4.000000     41.000000      0.000000      4.000000
# 50%      175.900000     12.000000    135.000000    275.000000     11.000000
# 75%      533.170000     36.000000    439.000000    593.000000     31.000000
# max    17700.230000    950.000000    733.000000    733.000000    765.000000
#
#        First_Transaction  Transaction_Channel1  Transaction_Channel2  \
# count       56185.000000          56185.000000          56185.000000
# mean          546.347477              8.955237             22.332455
# std           204.124640             16.563488             46.955261
# min             0.000000              0.000000              0.000000
# 25%           448.000000              0.000000              1.000000
# 50%           636.000000              3.000000              6.000000
# 75%           703.000000             11.000000             22.000000
# max           733.000000            393.000000            857.000000
#
#        Tr_Total_Value  Tr_Transaction  Tr_Unique_Items  Tr_First_Transaction  \
# count    56185.000000    56185.000000     56185.000000          56185.000000
# mean         5.203433        2.514581         2.396147              6.140765
# std          1.458653        1.407848         1.379134              0.767196
# min         -0.116534        0.000000         0.000000              0.000000
# 25%          4.094011        1.386294         1.386294              6.107023
# 50%          5.169916        2.484907         2.397895              6.456770
# 75%          6.278840        3.583519         3.433987              6.556778
# max          9.781333        6.856462         6.639876              6.598509
#
#          Tr_Recency     Tr_Tenure  Tr_Transaction_Channel1  \
# count  56185.000000  56185.000000             56185.000000
# mean       4.730941      3.986450                 1.395681
# std        1.518186      2.793266                 1.327389
# min        0.000000      0.000000                 0.000000
# 25%        3.737670      0.000000                 0.000000
# 50%        4.912655      5.620401                 1.386294
# 75%        6.086775      6.386879                 2.484907
# max        6.598509      6.598509                 5.976351
#
#        Tr_Transaction_Channel2
# count             56185.000000
# mean                  1.973926
# std                   1.543115
# min                   0.000000
# 25%                   0.693147
# 50%                   1.945910
# 75%                   3.135494
# max                   6.754604

# %%
sns.boxplot(x=processed_df['Tr_Total_Value'])

# Adding labels and title
plt.xlabel('Column Name')
plt.ylabel('Value')
plt.title('Boxplot of "Total Value"')

# Display the plot
plt.show()

# %%
# high = processed_df['Tr_Total_Value'].quantile(0.9975)
# low = processed_df['Tr_Total_Value'].quantile(0.0025)

# # only keep rows in the dataframe that are within the desired quantiles
# outlier_removed_df = processed_df[(processed_df['Tr_Total_Value'] < high) & (processed_df['Tr_Total_Value'] > low)]

# %%
# # silhouette_score = 0.378 for K = 4
# kmeans_df = processed_df[['Tr_Total_Value', 'Tr_Months_With_Transactions', "Tr_Latest_Transaction"]].copy()

# # silhouette_score = 0.361 for K = 4
# kmeans_df = processed_df[['Tr_Total_Value', 'Tr_Months_With_Transactions', "Tr_Latest_Transaction", "Tr_Price_Per_Item"]].copy()

# # silhouette_score = 0.347 for K = 4
# kmeans_df = processed_df[['Tr_Total_Value', 'Tr_Months_With_Transactions', "Tr_Latest_Transaction", "Tr_Per_Transaction_Value"]].copy()

# # silhouette_score = 0.340 for K = 4
# kmeans_df = processed_df[['Tr_Total_Value', 'Tr_Months_With_Transactions', "Tr_Latest_Transaction", "Tr_Unique_Items"]].copy()

# silhouette_score = 0.435 for K = 4
kmeans_df = processed_df[['Tr_First_Transaction', "Tr_Recency", "Tr_Total_Value"]].copy()

# # silhouette_score = 0.340 for K = 4
# kmeans_df = processed_df[['Tr_Total_Value', 'Tr_Months_With_Transactions', "Tr_Latest_Transaction", "Items_Per_Transaction"]].copy()

kmeans_df.describe()
# Out:
#        Tr_First_Transaction    Tr_Recency  Tr_Total_Value
# count          56185.000000  56185.000000    56185.000000
# mean               6.140765      4.730941        5.203433
# std                0.767196      1.518186        1.458653
# min                0.000000      0.000000       -0.116534
# 25%                6.107023      3.737670        4.094011
# 50%                6.456770      4.912655        5.169916
# 75%                6.556778      6.086775        6.278840
# max                6.598509      6.598509        9.781333

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

kmeans = KMeans(n_clusters=4, random_state=2042)
X = MinMaxScaler().fit_transform(kmeans_df)
kmeans.fit(X)

# Get the cluster labels
labels = kmeans.labels_

# Calculate the silhouette score
silhouette_avg = silhouette_score(X, labels)
print("Silhouette Score:", silhouette_avg)
# Out:
# Silhouette Score: 0.42625690196629823

# %%
cluster_labels = kmeans.labels_
cluster_sizes = pd.Series(cluster_labels).value_counts()

print(cluster_sizes)

processed_df['Cluster']  = labels
processed_df['Per_Transaction_Value'] = processed_df['Total_Value']/ processed_df['Transaction']
processed_df
# Out:
# 3    23955
# 1    17475
# 2     9592
# 0     5163
# dtype: int64
#                                                     Total_Value  Transaction  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...        82.94          7.0
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...       198.82         18.0
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...     15025.47        679.0
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...        50.06          4.0
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...       234.79         21.0
# ...                                                         ...          ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...        53.96          4.0
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...         4.99          1.0
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...        19.99          1.0
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...       180.55         15.0
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...        71.53          7.0
#
#                                                     Recency  Tenure  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...    440.0    18.0
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...     94.0   486.0
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...      8.0   714.0
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...     59.0   232.0
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...    263.0   323.0
# ...                                                     ...     ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...    169.0     0.0
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...    663.0     0.0
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...    544.0     0.0
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...    370.0   311.0
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...    101.0   623.0
#
#                                                     Unique_items  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...           7.0
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...          18.0
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...         555.0
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...           3.0
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...          21.0
# ...                                                          ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...           4.0
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...           1.0
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...           1.0
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...          15.0
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...           7.0
#
#                                                     First_Transaction  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...              458.0
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...              580.0
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...              722.0
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...              291.0
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...              586.0
# ...                                                               ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...              169.0
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...              663.0
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...              544.0
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...              681.0
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...              724.0
#
#                                                     Transaction_Channel1  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...                   0.0
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...                   0.0
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...                 117.0
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...                   0.0
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...                  13.0
# ...                                                                  ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...                   0.0
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...                   1.0
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...                   1.0
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...                   0.0
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...                   3.0
#
#                                                     Transaction_Channel2  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...                   7.0
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...                  18.0
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...                 562.0
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...                   4.0
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...                   8.0
# ...                                                                  ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...                   4.0
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...                   0.0
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...                   0.0
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...                  15.0
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...                   4.0
#
#                                                     Tr_Total_Value  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...        4.418117
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...        5.292400
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...        9.617502
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...        3.913222
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...        5.458691
# ...                                                            ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...        3.988243
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...        1.607436
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...        2.995232
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...        5.196008
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...        4.270117
#
#                                                     Tr_Transaction  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...        1.945910
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...        2.890372
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...        6.520621
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...        1.386294
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...        3.044522
# ...                                                            ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...        1.386294
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...        0.000000
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...        0.000000
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...        2.708050
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...        1.945910
#
#                                                     Tr_Unique_Items  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...         1.945910
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...         2.890372
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...         6.318968
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...         1.098612
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...         3.044522
# ...                                                             ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...         1.386294
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...         0.000000
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...         0.000000
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...         2.708050
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...         1.945910
#
#                                                     Tr_First_Transaction  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...              6.129050
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...              6.364751
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...              6.583409
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...              5.676754
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...              6.375025
# ...                                                                  ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...              5.135798
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...              6.498282
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...              6.300786
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...              6.525030
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...              6.586172
#
#                                                     Tr_Recency  Tr_Tenure  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...    6.089045   2.944439
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...    4.553877   6.188264
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...    2.197225   6.572283
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...    4.094345   5.451038
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...    5.575949   5.780744
# ...                                                        ...        ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...    5.135798   0.000000
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...    6.498282   0.000000
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...    6.300786   0.000000
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...    5.916202   5.743003
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...    4.624973   6.436150
#
#                                                     Tr_Transaction_Channel1  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...                 0.000000
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...                 0.000000
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...                 4.770685
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...                 0.000000
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...                 2.639057
# ...                                                                     ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...                 0.000000
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...                 0.693147
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...                 0.693147
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...                 0.000000
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...                 1.386294
#
#                                                     Tr_Transaction_Channel2  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...                 2.079442
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...                 2.944439
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...                 6.333280
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...                 1.609438
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...                 2.197225
# ...                                                                     ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...                 1.609438
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...                 0.000000
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...                 0.000000
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...                 2.772589
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...                 1.609438
#
#                                                     Cluster  \
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...        3
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...        1
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...        2
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...        0
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...        3
# ...                                                     ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...        3
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...        3
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...        3
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...        3
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...        1
#
#                                                     Per_Transaction_Value
# customer_id
# 0000d6c053fc8f9389d4565051f12402d5774aa4a9d2e5c...              11.848571
# 000114c6996ef5703a8d455faf2103f8488d3928348e073...              11.045556
# 0001d44dbe7f6c4b35200abdb052c77a87596fe1bdcc37e...              22.128822
# 00053f544468004bd5b18b25ae8faad7c9a2f71c34e7cde...              12.515000
# 000aa9a7d9f776173f87d58e834e4dd36f3a2d7908ae475...              11.180476
# ...                                                                   ...
# fffb00d134c84e6b71d3734c5261305fd2b1d200db0d172...              13.490000
# fffbe1daa0362090117b76308b8e52266db42e32ee1e7b4...               4.990000
# fffc76781a1ef4866728c8f7d1b38be48818ec4d0d6dda5...              19.990000
# fffe891a8d07a6883036b1d3f05bab5eecab29c6ef6b7b2...              12.036667
# fffec3dbcc87c78300f37f62cfca4274f1ea6ef59dba10f...              10.218571
#
# [56185 rows x 18 columns]

# %%
sns.boxplot(x='Cluster', y='Total_Value', data=processed_df, showfliers=False)
plt.show()
medians = processed_df.groupby(['Cluster'])['Total_Value'].median()

# Print the medians
print("Median Total Value for each cluster:")
print(medians)
# Out:
# Median Total Value for each cluster:
# Cluster
# 0     58.360
# 1    430.070
# 2    928.455
# 3     66.530
# Name: Total_Value, dtype: float64

# %%
sns.boxplot (x = 'Cluster', y = 'Recency', data = processed_df, showfliers=False)
plt.show()
medians = processed_df.groupby(['Cluster'])['Recency'].median()

# Print the medians
print("Median Recency for each cluster:")
print(medians)
# Out:
# Median Recency for each cluster:
# Cluster
# 0     62.0
# 1     82.0
# 2     12.0
# 3    495.0
# Name: Recency, dtype: float64

# %%
sns.boxplot (x = 'Cluster', y = 'Unique_items', data = processed_df, showfliers=False)
plt.show()

medians = processed_df.groupby(['Cluster'])['Unique_items'].median()

# Print the medians
print("Median Unique Items for each cluster:")
print(medians)
# Out:
# Median Unique Items for each cluster:
# Cluster
# 0     4.0
# 1    26.0
# 2    52.0
# 3     4.0
# Name: Unique_items, dtype: float64

# %%
sns.boxplot (x = 'Cluster', y = 'Transaction', data = processed_df, showfliers=False)
plt.show()
medians = processed_df.groupby(['Cluster'])['Transaction'].median()

# Print the medians
print("Median Transaction for each cluster:")
print(medians)
# Out:
# Median Transaction for each cluster:
# Cluster
# 0     4.0
# 1    29.0
# 2    60.0
# 3     5.0
# Name: Transaction, dtype: float64

# %%
sns.boxplot (x = 'Cluster', y = 'First_Transaction', data = processed_df, showfliers=False)
plt.show()

medians = processed_df.groupby(['Cluster'])['First_Transaction'].median()

# Print the medians
print("Median First Transaction for each cluster:")
print(medians)
# Out:
# Median First Transaction for each cluster:
# Cluster
# 0     87.0
# 1    668.0
# 2    697.0
# 3    612.0
# Name: First_Transaction, dtype: float64

# %%
sns.boxplot (x = 'Cluster', y = 'Per_Transaction_Value', data = processed_df, showfliers=False)
plt.show()
medians = processed_df.groupby(['Cluster'])['Per_Transaction_Value'].median()

# Print the medians
print("Median Per Transaction Value for each cluster:")
print(medians)
# Out:
# Median Per Transaction Value for each cluster:
# Cluster
# 0    14.490000
# 1    14.995455
# 2    15.783621
# 3    14.052500
# Name: Per_Transaction_Value, dtype: float64

# %%
sns.boxplot (x = 'Cluster', y = 'Transaction_Channel1', data = processed_df, showfliers=False)
plt.show()
medians = processed_df.groupby(['Cluster'])['Transaction_Channel1'].median()

# Print the medians
print("Median Overall_transaction_count_channel_1 for each cluster:")
print(medians)
# Out:
# Median Overall_transaction_count_channel_1 for each cluster:
# Cluster
# 0     0.0
# 1     7.0
# 2    13.0
# 3     1.0
# Name: Transaction_Channel1, dtype: float64

# %%
sns.boxplot (x = 'Cluster', y = 'Transaction_Channel2', data = processed_df, showfliers=False)
plt.show()
medians = processed_df.groupby(['Cluster'])['Transaction_Channel2'].median()

# Print the medians
print("Median Overall_transaction_count_channel_2 for each cluster:")
print(medians)
# Out:
# Median Overall_transaction_count_channel_2 for each cluster:
# Cluster
# 0     2.0
# 1    17.0
# 2    37.0
# 3     2.0
# Name: Transaction_Channel2, dtype: float64

# %%
df = df.merge(processed_df[['Cluster']], left_on='CUST NAME', right_index=True)

df.to_csv('df_with_cluster.csv', index=False)

# %%
processed_df.reset_index(inplace=True)
processed_df.to_csv('kmeans_clustering_first.csv', index=False)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import seaborn as sns

sse = {}
silhouette = {}

# Fit KMeans and calculate SSE and silhouette score for each k
for k in range(2, 10): # silhouette_score requires at least 2 clusters
    # Initialize KMeans with k clusters
    kmeans = KMeans(n_clusters=k, max_iter = 500, random_state=2042)
    
    # Fit KMeans on the normalized dataset
    kmeans.fit(X)
    
    # Assign sum of squared distances to k element of dictionary
    sse[k] = kmeans.inertia_

    # Predict the cluster labels for the dataset
    labels = kmeans.predict(X)
    
    # Calculate the silhouette score and add it to the silhouette dictionary
    silhouette[k] = silhouette_score(X, labels)

# Plotting the elbow plot
plt.figure(figsize=(12,8))
plt.title('The Elbow Method')
plt.xlabel('k'); 
plt.ylabel('Sum of squared errors')
sns.pointplot(x=list(sse.keys()), y=list(sse.values()))
plt.show()

# Plotting the silhouette scores
plt.figure(figsize=(12,8))
plt.title('Silhouette scores')
plt.xlabel('k'); 
plt.ylabel('Silhouette score')
sns.pointplot(x=list(silhouette.keys()), y=list(silhouette.values()))
plt.show()

# %%
highvalue_df = processed_df[processed_df['Cluster']==1]
highvalue_df

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
# silhouette_score = 0.435 for K = 4
kmeans_highvalue_df = highvalue_df[['Tr_Total_Value', 'Tr_Months_With_Transactions', "Tr_Latest_Transaction"]].copy()

kmeans = KMeans(n_clusters=3, random_state=2042)
Y = MinMaxScaler().fit_transform(kmeans_highvalue_df)
kmeans.fit(Y)

# Get the cluster labels
labels = kmeans.labels_

# Calculate the silhouette score
silhouette_avg = silhouette_score(Y, labels)
print("Silhouette Score:", silhouette_avg)

# %%
cluster_labels = kmeans.labels_
cluster_sizes = pd.Series(cluster_labels).value_counts()

print(cluster_sizes)

highvalue_df['Cluster']  = labels
highvalue_df['Average_Month_Value'] = highvalue_df['Total_Value']/ highvalue_df['Months_With_Transactions']

# %%
sns.boxplot(x='Cluster', y='Total_Value', data=highvalue_df, showfliers=False)
plt.show()
medians = highvalue_df.groupby(['Cluster'])['Total_Value'].median()

# Print the medians
print("Median Total Value for each cluster:")
print(medians)

# %%
sns.boxplot(x='Cluster', y='Latest_Transaction', data=highvalue_df, showfliers=False)
plt.show()
medians = highvalue_df.groupby(['Cluster'])['Latest_Transaction'].median()

# Print the medians
print("Median Latest Transaction for each cluster:")
print(medians)

# %%
sns.boxplot(x='Cluster', y='Per_Transaction_Value', data=highvalue_df, showfliers=False)
plt.show()
medians = highvalue_df.groupby(['Cluster'])['Per_Transaction_Value'].median()

# Print the medians
print("Median Per Transaction Value for each cluster:")
print(medians)

# %%
sns.boxplot(x='Cluster', y='Earliest_Transaction', data=highvalue_df, showfliers=False)
plt.show()
medians = highvalue_df.groupby(['Cluster'])['Earliest_Transaction'].median()

# Print the medians
print("Median Earliest Transaction for each cluster:")
print(medians)

# %%
sns.boxplot(x='Cluster', y='Transactions', data=highvalue_df, showfliers=False)
plt.show()
medians = highvalue_df.groupby(['Cluster'])['Transactions'].median()

# Print the medians
print("Median Transactions for each cluster:")
print(medians)

# %%
sns.boxplot(x='Cluster', y='Months_With_Transactions', data=highvalue_df, showfliers=False)
plt.show()
medians = highvalue_df.groupby(['Cluster'])['Months_With_Transactions'].median()

# Print the medians
print("Median Months_With_Transaction for each cluster:")
print(medians)

# %%
sns.boxplot(x='Cluster', y='Average_Month_Value', data=highvalue_df, showfliers=False)
plt.show()
medians = highvalue_df.groupby(['Cluster'])['Average_Month_Value'].median()

# Print the medians
print("Median Average_Month_Value for each cluster:")
print(medians)

# %%
highvalue_df.to_csv('kmeans_clustering_second.csv', index=False)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import seaborn as sns

sse = {}
silhouette = {}

# Fit KMeans and calculate SSE and silhouette score for each k
for k in range(2, 10): # silhouette_score requires at least 2 clusters
    # Initialize KMeans with k clusters
    kmeans = KMeans(n_clusters=k, max_iter = 500, random_state=2042)
    
    # Fit KMeans on the normalized dataset
    kmeans.fit(Y)
    
    # Assign sum of squared distances to k element of dictionary
    sse[k] = kmeans.inertia_

    # Predict the cluster labels for the dataset
    labels = kmeans.predict(Y)
    
    # Calculate the silhouette score and add it to the silhouette dictionary
    silhouette[k] = silhouette_score(Y, labels)

# Plotting the elbow plot
plt.figure(figsize=(12,8))
plt.title('The Elbow Method')
plt.xlabel('k'); 
plt.ylabel('Sum of squared errors')
sns.pointplot(x=list(sse.keys()), y=list(sse.values()))
plt.show()

# Plotting the silhouette scores
plt.figure(figsize=(12,8))
plt.title('Silhouette scores')
plt.xlabel('k'); 
plt.ylabel('Silhouette score')
sns.pointplot(x=list(silhouette.keys()), y=list(silhouette.values()))
plt.show()
